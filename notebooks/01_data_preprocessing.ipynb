# %% [markdown]
# # Data Preprocessing
#
# Notebook placeholder for dataset preparation steps.

# %% [markdown]
# ## Import Libraries

# %%
import os 
import cv2 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Explore Data Structure

# %%
dataset_path = r"D:\chest xray\chest_xray"

# %%
train_path = os.path.join(dataset_path, "train")
test_path = os.path.join(dataset_path, "test")
val_path = os.path.join(dataset_path, "val")

normal_train_path = os.path.join(train_path, "NORMAL")
pneumonia_train_path = os.path.join(train_path, "PNEUMONIA")

normal_test_path = os.path.join(test_path, "NORMAL")
pneumonia_test_path = os.path.join(test_path, "PNEUMONIA")

normal_val_path = os.path.join(val_path, "NORMAL")
pneumonia_val_path = os.path.join(val_path, "PNEUMONIA")

# %%
normal_train_path = os.path.join(dataset_path, "train", "NORMAL")

print(len(os.listdir(normal_train_path)))
# Out:
# 1341

# %% [markdown]
# ## Visualize Sample X-Ray Images

# %%
normal_images = os.listdir(normal_train_path)
first_image_name = normal_images[0]
first_image_path = os.path.join(normal_train_path , first_image_name)
print(first_image_path)
# Out:
# D:\chest xray\chest_xray\train\NORMAL\IM-0115-0001.jpeg

# %%
image = cv2.imread(first_image_path)
print(type(image))
print(image.shape)
# Out:
# <class 'numpy.ndarray'>
# (1858, 2090, 3)

# %%
plt.imshow(image)
plt.axis("off")
plt.show()

# %%
print(image[0][0])
# Out:
# [22 22 22]

# %%
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(image_rgb)
plt.axis("off")
plt.show()

# %%
gray_image = cv2.cvtColor(image_rgb, cv2.COLOR_RGB2GRAY)

# %%
print(image.shape)
print(gray_image.shape)
# Out:
# (1858, 2090, 3)
# (1858, 2090)

# %%
plt.figure(figsize=(6,6))
plt.imshow(gray_image, cmap="gray")
plt.title("Grayscale Chest X-ray")
plt.axis("off")
plt.show()

# %%
resized_image = cv2.resize(gray_image ,(224,224))

# %%
print(gray_image.shape)
print(resized_image.shape)
# Out:
# (1858, 2090)
# (224, 224)

# %%
plt.figure(figsize=(5,5))
plt.imshow(resized_image, cmap="gray")
plt.title("Resized Image (224 × 224)")
plt.axis("off")
plt.show()

# %%
normalized_image = resized_image / 255.0

# %%
print(resized_image.dtype)
print(normalized_image.dtype)
# Out:
# uint8
# float64

# %%
x = []
y = []

for image_name in os.listdir(normal_train_path):

    image_path = os.path.join(normal_train_path, image_name)

    image = cv2.imread(image_path)

    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

    gray_image = cv2.cvtColor(image_rgb, cv2.COLOR_RGB2GRAY)

    resized_image = cv2.resize(gray_image, (224, 224))

    normalized_image = resized_image / 255.0

    x.append(normalized_image)
    y.append(0)

# %%
print(len(x))
print(len(y))
# Out:
# 1341
# 1341
